# %%
#!pip install opencv-python
#!pip install opencv-contrib-python
#!pip install ultralytics
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import cv2
import  numpy as np
from ultralytics import YOLO

model = YOLO('minecraft_player detection 02 (cpu).pt')

cap = cv2.VideoCapture('Desktop/video_dataset/minecraft-pvp-montage-a-l-ancienne-planetpvp-2.mp4')

# create a dictionary of all trackers in OpenCV that can be used for tracking
OPENCV_OBJECT_TRACKERS = {
	"csrt": cv2.legacy.TrackerCSRT_create, # peu grossir/rapetir est 7/10
	"kcf": cv2.legacy.TrackerKCF_create, # 5/10 
	"boosting": cv2.legacy.TrackerBoosting_create,# 3/10  n'arete pas de tracker
	"mil": cv2.legacy.TrackerMIL_create,# 3/10  n'arete pas de tracker
	"tld": cv2.legacy.TrackerTLD_create,# 4/10  n'arete pas de tracker mais retrouve des chose semblable
	"medianflow": cv2.legacy.TrackerMedianFlow_create,# 4/10  n'arete pas de tracker mais retrouve des chose semblable
	"mosse": cv2.legacy.TrackerMOSSE_create# 4/10  n'arete pas de tracker 
}


# Create MultiTracker object
trackers = cv2.legacy.MultiTracker_create()
compteur = 0
while True:
    frame = cap.read()[1]

    if frame is None:
        break
    frame = cv2.resize(frame,(1090,600))
    
    (success, boxes) = trackers.update(frame)
    #print(boxes)
    
    # loop over the bounding boxes and draw then on the frame
    if success == False:
        bound_boxes = trackers.getObjects()
        idx = np.where(bound_boxes.sum(axis= 1) != 0)[0]
        bound_boxes = bound_boxes[idx]
        trackers = cv2.legacy.MultiTracker_create()
        
        for bound_box in bound_boxes:
            trackers.add(tracker,frame,bound_box)
    
    if compteur % 1 == 0: # detect new player
        result = model(frame)
        result = result[0]
        for idx in range(len(result.boxes)):
            box = result.boxes[idx]
            pos = box.xyxy[0]

            x1 = int(pos[0].item())
            y1 = int(pos[1].item())

            x2 = int(pos[2].item())
            y2 = int(pos[3].item())
            
            w = x2 - x1
            h = y2 - y1
            
            bound_box = (x1, y1, w, h)
            tracker = OPENCV_OBJECT_TRACKERS['csrt']()
            trackers.add(tracker, frame, bound_box)
            print(trackers)
            """
            if boxes == ():
                boxes = []
                boxes.append([x1, y1, w, h])
                print("1 :", boxes)
            else:
                try:
                    boxes = boxes.tolist()
                except:
                    pass
                    
                boxes.append([x1, y1, w, h])
                print("2 ", boxes)
            """
    compteur += 1
    
        
    for i,box in enumerate(boxes):
        #print("box : ", box)
        (x, y, w, h) = [int(v) for v in box]
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow('Frame', frame)
    k = cv2.waitKey(30)

    if k == ord("s"): 
        # select the bounding box of the object we want to track (make
        # sure you press ENTER or SPACE after selecting the ROI)
        roi = cv2.selectROI("Frame", frame, fromCenter=False,
                            showCrosshair=True)
        # create a new object tracker for the bounding box and add it
        # to our multi-object tracker
        tracker = OPENCV_OBJECT_TRACKERS['csrt']()
        trackers.add(tracker, frame, roi)


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 (no detections), 61.1ms
# Speed: 1.9ms preprocess, 61.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 47.3ms
# Speed: 1.2ms preprocess, 47.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 69.9ms
# Speed: 1.2ms preprocess, 69.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.9ms
# Speed: 1.3ms preprocess, 56.9ms inference, 0.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 67.1ms
# Speed: 1.4ms preprocess, 67.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.4ms
# Speed: 1.3ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 60.1ms
# Speed: 1.4ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 60.8ms
# Speed: 1.5ms preprocess, 60.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 60.9ms
# Speed: 1.5ms preprocess, 60.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 61.3ms
# Speed: 1.3ms preprocess, 61.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 2 players, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 59.3ms
# Speed: 1.3ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 60.1ms
# Speed: 1.4ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 55.8ms
# Speed: 1.3ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 57.1ms
# Speed: 1.4ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 66.3ms
# Speed: 1.4ms preprocess, 66.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 (no detections), 61.8ms
# Speed: 1.3ms preprocess, 61.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.1ms
# Speed: 1.3ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 66.6ms
# Speed: 1.7ms preprocess, 66.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 2 players, 57.0ms
# Speed: 1.3ms preprocess, 57.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 51.4ms
# Speed: 1.5ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 2 players, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.3ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
#
# 0: 352x640 1 player, 58.0ms
# Speed: 1.3ms preprocess, 58.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# < cv2.legacy.MultiTracker 0x29952c590>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 31
#      28     break
#      29 frame = cv2.resize(frame,(1090,600))
# ---> 31 (success, boxes) = trackers.update(frame)
#      32 #print(boxes)
#      33
#      34 # loop over the bounding boxes and draw then on the frame
#      35 if success == False:
#
# KeyboardInterrupt:

# %%
print(result[0].boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (600, 1090)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))

# %%
import cv2
import  numpy as np
from ultralytics import YOLO

model = YOLO('minecraft_player detection 02 (cpu).pt')

cap = cv2.VideoCapture('Desktop/video_dataset/minecraft-pvp-montage-a-l-ancienne-planetpvp-2.mp4')

# create a dictionary of all trackers in OpenCV that can be used for tracking
OPENCV_OBJECT_TRACKERS = {
	"csrt": cv2.legacy.TrackerCSRT_create, # peu grossir/rapetir est 7/10
	"kcf": cv2.legacy.TrackerKCF_create, # 5/10 
	"boosting": cv2.legacy.TrackerBoosting_create,# 3/10  n'arete pas de tracker
	"mil": cv2.legacy.TrackerMIL_create,# 3/10  n'arete pas de tracker
	"tld": cv2.legacy.TrackerTLD_create,# 4/10  n'arete pas de tracker mais retrouve des chose semblable
	"medianflow": cv2.legacy.TrackerMedianFlow_create,# 4/10  n'arete pas de tracker mais retrouve des chose semblable
	"mosse": cv2.legacy.TrackerMOSSE_create# 4/10  n'arete pas de tracker 
}


# Create MultiTracker object
trackers = cv2.legacy.MultiTracker_create()
compteur = 0
while True:
    boxes = []
    frame = cap.read()[1]

    if frame is None:
        break
    frame = cv2.resize(frame,(1090,600))
    
    
    
    result = model(frame)
    result = result[0]
    for idx in range(len(result.boxes)):
        box = result.boxes[idx]
        pos = box.xyxy[0]

        x1 = int(pos[0].item())
        y1 = int(pos[1].item())

        x2 = int(pos[2].item())
        y2 = int(pos[3].item())

        w = x2 - x1
        h = y2 - y1

        bound_box = (x1, y1, w, h)
        tracker = OPENCV_OBJECT_TRACKERS['csrt']()
        trackers.add(tracker, frame, bound_box)
        
        if boxes == ():
            boxes = []
            boxes.append([x1, y1, w, h])
            print("1 :", boxes)
        else:
            try:
                boxes = boxes.tolist()
            except:
                pass

            boxes.append([x1, y1, w, h])
            print("2 ", boxes)
        
    
        
    for i,box in enumerate(boxes):
        #print("box : ", box)
        (x, y, w, h) = [int(v) for v in box]
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow('Frame', frame)
    k = cv2.waitKey(30)

    if k == ord("s"): 
        # select the bounding box of the object we want to track (make
        # sure you press ENTER or SPACE after selecting the ROI)
        roi = cv2.selectROI("Frame", frame, fromCenter=False,
                            showCrosshair=True)
        # create a new object tracker for the bounding box and add it
        # to our multi-object tracker
        tracker = OPENCV_OBJECT_TRACKERS['csrt']()
        trackers.add(tracker, frame, roi)


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 (no detections), 52.3ms
# Speed: 2.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.2ms
# Speed: 1.3ms preprocess, 50.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 69.2ms
# Speed: 1.1ms preprocess, 69.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 61.4ms
# Speed: 1.4ms preprocess, 61.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 58.1ms
# Speed: 1.1ms preprocess, 58.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 62.2ms
# Speed: 1.2ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 60.7ms
# Speed: 1.2ms preprocess, 60.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[1004, 378, 18, 31]]
#
# 0: 352x640 (no detections), 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 56.4ms
# Speed: 1.5ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[983, 391, 17, 29]]
#
# 0: 352x640 1 player, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[976, 391, 19, 34]]
#
# 0: 352x640 (no detections), 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.7ms
# Speed: 2.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[961, 403, 18, 33]]
#
# 0: 352x640 1 player, 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[954, 406, 18, 34]]
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[947, 407, 18, 31]]
#
# 0: 352x640 2 players, 62.2ms
# Speed: 1.4ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[941, 414, 19, 33]]
# 2  [[941, 414, 19, 33], [939, 413, 19, 42]]
#
# 0: 352x640 1 player, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[937, 415, 16, 31]]
#
# 0: 352x640 (no detections), 56.9ms
# Speed: 1.1ms preprocess, 56.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[927, 418, 17, 28]]
# 2  [[927, 418, 17, 28], [671, 0, 293, 538]]
#
# 0: 352x640 1 player, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[921, 419, 17, 27]]
#
# 0: 352x640 (no detections), 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 56.5ms
# Speed: 1.3ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[669, 0, 293, 531]]
#
# 0: 352x640 1 player, 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[660, 0, 295, 525]]
#
# 0: 352x640 1 player, 55.9ms
# Speed: 1.2ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[638, 0, 312, 497]]
#
# 0: 352x640 1 player, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[641, 0, 307, 503]]
#
# 0: 352x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 54.8ms
# Speed: 1.2ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[622, 0, 316, 535]]
# 2  [[622, 0, 316, 535], [620, 424, 49, 54]]
#
# 0: 352x640 (no detections), 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[868, 423, 16, 26]]
# 2  [[868, 423, 16, 26], [617, 0, 322, 536]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[617, 0, 307, 540]]
#
# 0: 352x640 1 player, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[611, 0, 295, 492]]
#
# 0: 352x640 1 player, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[614, 0, 294, 512]]
#
# 0: 352x640 2 players, 51.8ms
# Speed: 1.3ms preprocess, 51.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[960, 1, 127, 178]]
# 2  [[960, 1, 127, 178], [608, 0, 291, 517]]
#
# 0: 352x640 1 player, 58.5ms
# Speed: 1.2ms preprocess, 58.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[959, 1, 128, 181]]
#
# 0: 352x640 2 players, 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[952, 1, 134, 182]]
# 2  [[952, 1, 134, 182], [611, 0, 279, 460]]
#
# 0: 352x640 1 player, 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[951, 1, 134, 183]]
#
# 0: 352x640 1 player, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[948, 2, 135, 182]]
#
# 0: 352x640 1 player, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[946, 2, 133, 181]]
#
# 0: 352x640 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.1ms
# Speed: 1.2ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 players, 48.7ms
# Speed: 1.4ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[404, 0, 137, 144]]
# 2  [[404, 0, 137, 144], [912, 0, 157, 174]]
#
# 0: 352x640 (no detections), 55.5ms
# Speed: 1.1ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[390, 0, 130, 138]]
#
# 0: 352x640 1 player, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[387, 0, 133, 138]]
#
# 0: 352x640 1 player, 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[387, 0, 143, 148]]
#
# 0: 352x640 1 player, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[384, 0, 132, 147]]
#
# 0: 352x640 1 player, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[383, 0, 127, 151]]
#
# 0: 352x640 1 player, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[370, 0, 140, 142]]
#
# 0: 352x640 1 player, 54.4ms
# Speed: 1.1ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[373, 0, 138, 150]]
#
# 0: 352x640 1 player, 59.4ms
# Speed: 1.1ms preprocess, 59.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[367, 0, 145, 144]]
#
# 0: 352x640 1 player, 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[367, 0, 138, 139]]
#
# 0: 352x640 1 player, 57.0ms
# Speed: 1.3ms preprocess, 57.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[350, 0, 158, 136]]
#
# 0: 352x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 62.1ms
# Speed: 1.4ms preprocess, 62.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[337, 0, 167, 140]]
#
# 0: 352x640 1 player, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[339, 0, 160, 136]]
#
# 0: 352x640 1 player, 56.5ms
# Speed: 1.1ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[340, 0, 159, 139]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[339, 0, 136, 143]]
#
# 0: 352x640 (no detections), 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[307, 0, 189, 140]]
#
# 0: 352x640 1 player, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[876, 0, 92, 163]]
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[286, 0, 205, 139]]
#
# 0: 352x640 2 players, 58.0ms
# Speed: 1.2ms preprocess, 58.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[290, 0, 180, 144]]
# 2  [[290, 0, 180, 144], [872, 0, 78, 131]]
#
# 0: 352x640 1 player, 51.4ms
# Speed: 1.4ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[284, 0, 188, 147]]
#
# 0: 352x640 1 player, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[282, 0, 197, 146]]
#
# 0: 352x640 (no detections), 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 56.7ms
# Speed: 1.3ms preprocess, 56.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[261, 0, 211, 144]]
#
# 0: 352x640 1 player, 54.5ms
# Speed: 1.3ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[237, 0, 214, 143]]
#
# 0: 352x640 2 players, 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[242, 0, 200, 141]]
# 2  [[242, 0, 200, 141], [407, 423, 22, 35]]
#
# 0: 352x640 1 player, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[255, 0, 190, 143]]
#
# 0: 352x640 1 player, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[239, 0, 209, 141]]
#
# 0: 352x640 1 player, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[241, 0, 197, 142]]
#
# 0: 352x640 1 player, 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[243, 0, 193, 142]]
#
# 0: 352x640 1 player, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[250, 0, 192, 140]]
#
# 0: 352x640 1 player, 55.5ms
# Speed: 1.2ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[258, 0, 177, 140]]
#
# 0: 352x640 1 player, 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[237, 0, 191, 139]]
#
# 0: 352x640 1 player, 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[242, 0, 186, 137]]
#
# 0: 352x640 1 player, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[258, 0, 163, 138]]
#
# 0: 352x640 1 player, 54.3ms
# Speed: 1.3ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[250, 0, 175, 139]]
#
# 0: 352x640 1 player, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[259, 0, 163, 143]]
#
# 0: 352x640 2 players, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[241, 0, 180, 142]]
# 2  [[241, 0, 180, 142], [886, 0, 203, 549]]
#
# 0: 352x640 2 players, 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[233, 0, 190, 139]]
# 2  [[233, 0, 190, 139], [884, 0, 205, 550]]
#
# 0: 352x640 1 player, 54.1ms
# Speed: 1.2ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[226, 0, 198, 137]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[217, 0, 202, 122]]
#
# 0: 352x640 (no detections), 58.0ms
# Speed: 1.2ms preprocess, 58.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[880, 0, 209, 558]]
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[881, 0, 208, 501]]
#
# 0: 352x640 2 players, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[881, 0, 208, 518]]
# 2  [[881, 0, 208, 518], [216, 0, 180, 138]]
#
# 0: 352x640 2 players, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[881, 0, 208, 545]]
# 2  [[881, 0, 208, 545], [492, 0, 360, 487]]
#
# 0: 352x640 1 player, 55.3ms
# Speed: 1.3ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[679, 445, 17, 44]]
#
# 0: 352x640 1 player, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[673, 445, 19, 44]]
#
# 0: 352x640 2 players, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[366, 457, 60, 123]]
# 2  [[366, 457, 60, 123], [881, 1, 207, 505]]
# 0: 352x640 3 players, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[359, 457, 52, 113]]
# 2  [[359, 457, 52, 113], [881, 2, 208, 447]]
# 2  [[359, 457, 52, 113], [881, 2, 208, 447], [666, 444, 18, 45]]
#
# 0: 352x640 1 player, 61.4ms
# Speed: 1.2ms preprocess, 61.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[878, 1, 210, 449]]
#
# 0: 352x640 2 players, 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[324, 454, 53, 107]]
# 2  [[324, 454, 53, 107], [876, 3, 212, 442]]
#
# 0: 352x640 2 players, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[878, 4, 211, 438]]
# 2  [[878, 4, 211, 438], [321, 455, 49, 102]]
#
# 0: 352x640 1 player, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[878, 3, 210, 439]]
#
# 0: 352x640 1 player, 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[879, 4, 209, 441]]
#
# 0: 352x640 (no detections), 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 62.5ms
# Speed: 1.5ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[263, 454, 62, 109]]
#
# 0: 352x640 (no detections), 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.4ms
# Speed: 1.4ms preprocess, 51.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.9ms
# Speed: 1.2ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 1.1ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[85, 435, 67, 120]]
#
# 0: 352x640 1 player, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[70, 436, 59, 117]]
#
# 0: 352x640 1 player, 55.8ms
# Speed: 1.2ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[501, 441, 24, 48]]
#
# 0: 352x640 1 player, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[500, 441, 25, 47]]
#
# 0: 352x640 (no detections), 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.4ms
# Speed: 1.1ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 59.1ms
# Speed: 1.1ms preprocess, 59.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.6ms
# Speed: 1.2ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.9ms
# Speed: 1.5ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 59.0ms
# Speed: 1.3ms preprocess, 59.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[0, 448, 108, 152]]
#
# 0: 352x640 (no detections), 57.7ms
# Speed: 1.1ms preprocess, 57.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 62.7ms
# Speed: 1.2ms preprocess, 62.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.0ms
# Speed: 1.2ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[0, 432, 55, 134]]
#
# 0: 352x640 (no detections), 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
# 0: 352x640 1 player, 79.8ms
# Speed: 1.1ms preprocess, 79.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[0, 422, 16, 125]]
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[149, 539, 55, 60]]
#
# 0: 352x640 1 player, 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[176, 400, 31, 66]]
#
# 0: 352x640 (no detections), 59.9ms
# Speed: 1.4ms preprocess, 59.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.2ms
# Speed: 1.5ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[56, 531, 56, 68]]
#
# 0: 352x640 2 players, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[107, 399, 36, 58]]
# 2  [[107, 399, 36, 58], [17, 528, 72, 71]]
#
# 0: 352x640 2 players, 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[100, 398, 38, 58]]
# 2  [[100, 398, 38, 58], [95, 411, 31, 48]]
#
# 0: 352x640 2 players, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[83, 397, 42, 55]]
# 2  [[83, 397, 42, 55], [80, 400, 35, 57]]
#
# 0: 352x640 2 players, 57.4ms
# Speed: 1.2ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[69, 397, 49, 59]]
# 2  [[69, 397, 49, 59], [70, 410, 32, 47]]
#
# 0: 352x640 1 player, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[57, 397, 44, 59]]
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.3ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[39, 398, 39, 58]]
#
# 0: 352x640 1 player, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[26, 398, 40, 60]]
#
# 0: 352x640 1 player, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[12, 398, 39, 62]]
#
# 0: 352x640 1 player, 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[1, 401, 34, 61]]
#
# 0: 352x640 1 player, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[0, 398, 17, 89]]
#
# 0: 352x640 (no detections), 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.8ms
# Speed: 1.3ms preprocess, 50.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.0ms
# Speed: 1.2ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 52.0ms
# Speed: 1.2ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[786, 487, 190, 112]]
#
# 0: 352x640 (no detections), 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 55.4ms
# Speed: 1.2ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[761, 486, 211, 113]]
#
# 0: 352x640 (no detections), 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[767, 487, 203, 112]]
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[767, 488, 184, 111]]
#
# 0: 352x640 (no detections), 51.9ms
# Speed: 1.2ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[709, 487, 183, 112]]
#
# 0: 352x640 (no detections), 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.8ms
# Speed: 1.5ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.0ms
# Speed: 1.1ms preprocess, 56.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 1.2ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.2ms
# Speed: 1.2ms preprocess, 56.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 59.0ms
# Speed: 1.2ms preprocess, 59.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 1.5ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.4ms
# Speed: 1.1ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 74.5ms
# Speed: 1.6ms preprocess, 74.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[917, 386, 18, 35]]
#
# 0: 352x640 1 player, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[911, 388, 16, 33]]
#
# 0: 352x640 (no detections), 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.8ms
# Speed: 1.5ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 56.3ms
# Speed: 1.3ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 0: 352x640 1 player, 62.7ms
# Speed: 1.2ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[897, 388, 17, 32]]
#
# 0: 352x640 (no detections), 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[882, 386, 17, 30]]
#
# 0: 352x640 (no detections), 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 64.2ms
# Speed: 1.2ms preprocess, 64.2ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 58.3ms
# Speed: 1.2ms preprocess, 58.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.4ms
# Speed: 1.1ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 62.8ms
# Speed: 1.2ms preprocess, 62.8ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 player, 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[859, 388, 19, 33]]
#
# 0: 352x640 1 player, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[855, 388, 22, 34]]
#
# 0: 352x640 1 player, 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[856, 388, 20, 34]]
#
# 0: 352x640 1 player, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[856, 388, 18, 34]]
#
# 0: 352x640 1 player, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[854, 388, 17, 35]]
#
# 0: 352x640 1 player, 55.7ms
# Speed: 1.1ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[853, 388, 19, 36]]
#
# 0: 352x640 1 player, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[857, 389, 17, 35]]
#
# 0: 352x640 1 player, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[858, 388, 17, 36]]
#
# 0: 352x640 1 player, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[858, 389, 18, 36]]
#
# 0: 352x640 2 players, 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[858, 389, 20, 39]]
# 2  [[858, 389, 20, 39], [353, 64, 95, 164]]
#
# 0: 352x640 1 player, 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[857, 391, 21, 37]]
#
# 0: 352x640 1 player, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[854, 397, 20, 34]]
#
# 0: 352x640 1 player, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[854, 396, 19, 36]]
#
# 0: 352x640 1 player, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[852, 397, 19, 35]]
#
# 0: 352x640 1 player, 44.0ms
# Speed: 1.3ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[851, 399, 20, 34]]
#
# 0: 352x640 1 player, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[852, 400, 18, 35]]
#
# 0: 352x640 2 players, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[850, 400, 19, 36]]
# 2  [[850, 400, 19, 36], [328, 68, 126, 167]]
#
# 0: 352x640 1 player, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[849, 401, 18, 37]]
#
# 0: 352x640 1 player, 54.8ms
# Speed: 1.2ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[848, 401, 18, 37]]
#
# 0: 352x640 1 player, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[845, 402, 21, 40]]
#
# 0: 352x640 1 player, 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[844, 403, 20, 38]]
#
# 0: 352x640 1 player, 54.8ms
# Speed: 1.3ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[840, 403, 23, 39]]
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[838, 403, 24, 39]]
#
# 0: 352x640 1 player, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[836, 402, 23, 41]]
#
# 0: 352x640 1 player, 54.4ms
# Speed: 1.3ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[834, 402, 23, 42]]
#
# 0: 352x640 1 player, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[832, 405, 20, 39]]
#
# 0: 352x640 1 player, 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[830, 405, 22, 39]]
#
# 0: 352x640 1 player, 51.9ms
# Speed: 1.3ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[826, 409, 19, 38]]
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[826, 409, 18, 39]]
#
# 0: 352x640 1 player, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[822, 408, 20, 40]]
#
# 0: 352x640 1 player, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[821, 408, 20, 41]]
#
# 0: 352x640 1 player, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[818, 408, 21, 41]]
#
# 0: 352x640 1 player, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[813, 411, 20, 42]]
#
# 0: 352x640 1 player, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[811, 411, 19, 43]]
#
# 0: 352x640 1 player, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[807, 412, 22, 44]]
#
# 0: 352x640 1 player, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[805, 416, 20, 40]]
#
# 0: 352x640 1 player, 54.4ms
# Speed: 1.2ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[803, 415, 21, 41]]
#
# 0: 352x640 1 player, 64.9ms
# Speed: 1.2ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[799, 414, 19, 43]]
#
# 0: 352x640 1 player, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[794, 415, 22, 42]]
#
# 0: 352x640 1 player, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[792, 415, 20, 41]]
#
# 0: 352x640 1 player, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[788, 413, 22, 42]]
#
# 0: 352x640 1 player, 54.6ms
# Speed: 1.1ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[783, 410, 22, 44]]
#
# 0: 352x640 1 player, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[781, 410, 20, 40]]
#
# 0: 352x640 1 player, 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[777, 408, 22, 43]]
#
# 0: 352x640 1 player, 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[773, 408, 22, 40]]
#
# 0: 352x640 1 player, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[770, 408, 21, 42]]
#
# 0: 352x640 1 player, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[765, 406, 20, 47]]
#
# 0: 352x640 1 player, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[762, 406, 20, 45]]
#
# 0: 352x640 1 player, 47.4ms
# Speed: 1.1ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[758, 404, 19, 49]]
#
# 0: 352x640 1 player, 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[754, 405, 21, 50]]
#
# 0: 352x640 1 player, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[751, 406, 23, 48]]
#
# 0: 352x640 1 player, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[746, 408, 24, 45]]
#
# 0: 352x640 1 player, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[742, 408, 21, 46]]
#
# 0: 352x640 1 player, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[736, 408, 26, 47]]
#
# 0: 352x640 1 player, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[733, 408, 26, 48]]
#
# 0: 352x640 1 player, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[728, 410, 25, 48]]
#
# 0: 352x640 1 player, 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[726, 414, 24, 45]]
#
# 0: 352x640 1 player, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[720, 415, 25, 48]]
#
# 0: 352x640 1 player, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[717, 416, 24, 51]]
#
# 0: 352x640 1 player, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[709, 420, 26, 49]]
#
# 0: 352x640 1 player, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[703, 421, 26, 51]]
#
# 0: 352x640 1 player, 45.7ms
# Speed: 1.1ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[697, 426, 24, 48]]
#
# 0: 352x640 1 player, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[693, 427, 27, 52]]
#
# 0: 352x640 1 player, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[686, 429, 28, 51]]
#
# 0: 352x640 1 player, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[682, 430, 25, 51]]
#
# 0: 352x640 1 player, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[679, 430, 27, 54]]
#
# 0: 352x640 1 player, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[678, 433, 27, 53]]
#
# 0: 352x640 1 player, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[677, 435, 29, 54]]
#
# 0: 352x640 1 player, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[673, 436, 30, 55]]
#
# 0: 352x640 1 player, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[670, 437, 33, 58]]
#
# 0: 352x640 1 player, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[669, 442, 32, 57]]
#
# 0: 352x640 1 player, 56.5ms
# Speed: 1.2ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[667, 444, 34, 59]]
#
# 0: 352x640 1 player, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[664, 447, 34, 58]]
#
# 0: 352x640 1 player, 49.0ms
# Speed: 1.2ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[664, 450, 33, 61]]
#
# 0: 352x640 1 player, 57.2ms
# Speed: 1.2ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[662, 456, 38, 63]]
#
# 0: 352x640 1 player, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[660, 458, 36, 64]]
#
# 0: 352x640 1 player, 54.4ms
# Speed: 1.2ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[655, 463, 41, 69]]
#
# 0: 352x640 1 player, 51.0ms
# Speed: 1.4ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[653, 467, 41, 69]]
#
# 0: 352x640 1 player, 54.8ms
# Speed: 1.1ms preprocess, 54.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[652, 473, 40, 65]]
#
# 0: 352x640 1 player, 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[646, 479, 49, 68]]
#
# 0: 352x640 1 player, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[640, 486, 53, 83]]
#
# 0: 352x640 1 player, 58.1ms
# ...
# 2  [[490, 235, 100, 205]]
# 2  [[490, 235, 100, 205], [418, 310, 24, 43]]
#
# 0: 352x640 1 player, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[495, 232, 93, 197]]
#
# 0: 352x640 2 players, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[500, 240, 98, 197]]
# 2  [[500, 240, 98, 197], [176, 272, 38, 53]]
#
# 0: 352x640 2 players, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[509, 242, 103, 196]]
# 2  [[509, 242, 103, 196], [150, 257, 40, 60]]
#
# 0: 352x640 3 players, 49.6ms
# Speed: 1.4ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[135, 246, 42, 72]]
# 2  [[135, 246, 42, 72], [524, 236, 115, 220]]
# 2  [[135, 246, 42, 72], [524, 236, 115, 220], [410, 274, 23, 42]]
#
# 0: 352x640 1 player, 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[536, 230, 120, 229]]
#
# 0: 352x640 1 player, 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[519, 220, 132, 237]]
#
# 0: 352x640 1 player, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[482, 206, 151, 281]]
#
# 0: 352x640 2 players, 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[468, 188, 171, 350]]
# 2  [[468, 188, 171, 350], [113, 243, 52, 85]]
#
# 0: 352x640 1 player, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[478, 183, 175, 359]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 190, 195, 349]]
#
# 0: 352x640 1 player, 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[503, 175, 199, 278]]
#
# 0: 352x640 1 player, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[467, 147, 165, 252]]
#
# 0: 352x640 1 player, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[364, 121, 199, 274]]
#
# 0: 352x640 1 player, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[315, 90, 184, 337]]
#
# 0: 352x640 1 player, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[321, 77, 160, 374]]
#
# 0: 352x640 1 player, 56.5ms
# Speed: 1.3ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[359, 104, 167, 335]]
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.3ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[428, 121, 159, 281]]
#
# 0: 352x640 1 player, 50.4ms
# Speed: 1.3ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[458, 125, 170, 271]]
#
# 0: 352x640 1 player, 56.8ms
# Speed: 1.4ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[484, 137, 175, 274]]
#
# 0: 352x640 1 player, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[498, 143, 171, 277]]
#
# 0: 352x640 1 player, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[498, 148, 243, 306]]
#
# 0: 352x640 1 player, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[506, 158, 199, 344]]
#
# 0: 352x640 1 player, 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[503, 162, 187, 365]]
#
# 0: 352x640 1 player, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[487, 168, 167, 351]]
#
# 0: 352x640 1 player, 47.4ms
# Speed: 1.4ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[469, 145, 168, 332]]
#
# 0: 352x640 2 players, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[395, 137, 227, 271]]
# 2  [[395, 137, 227, 271], [439, 137, 167, 255]]
#
# 0: 352x640 1 player, 49.2ms
# Speed: 1.4ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[395, 123, 224, 266]]
#
# 0: 352x640 1 player, 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[396, 119, 222, 266]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[405, 110, 190, 282]]
#
# 0: 352x640 1 player, 53.9ms
# Speed: 1.3ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[464, 132, 144, 298]]
#
# 0: 352x640 1 player, 58.3ms
# Speed: 1.4ms preprocess, 58.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[487, 135, 117, 298]]
#
# 0: 352x640 1 player, 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[474, 135, 175, 278]]
#
# 0: 352x640 1 player, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[467, 146, 191, 257]]
#
# 0: 352x640 1 player, 55.7ms
# Speed: 1.2ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[471, 153, 182, 239]]
#
# 0: 352x640 1 player, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 151, 162, 245]]
#
# 0: 352x640 1 player, 52.9ms
# Speed: 1.3ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[468, 144, 190, 304]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.7ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[498, 156, 152, 361]]
#
# 0: 352x640 1 player, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[488, 165, 166, 354]]
#
# 0: 352x640 1 player, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[491, 180, 173, 303]]
#
# 0: 352x640 1 player, 53.2ms
# Speed: 1.3ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[461, 172, 192, 271]]
#
# 0: 352x640 1 player, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[456, 176, 192, 241]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[445, 183, 146, 222]]
#
# 0: 352x640 1 player, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[423, 185, 143, 207]]
#
# 0: 352x640 1 player, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[433, 176, 115, 234]]
#
# 0: 352x640 1 player, 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[447, 173, 101, 239]]
#
# 0: 352x640 1 player, 57.6ms
# Speed: 1.3ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[449, 192, 96, 205]]
#
# 0: 352x640 1 player, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[460, 209, 99, 177]]
#
# 0: 352x640 1 player, 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[470, 216, 96, 160]]
#
# 0: 352x640 1 player, 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[473, 225, 105, 158]]
#
# 0: 352x640 2 players, 54.1ms
# Speed: 1.3ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[501, 200, 84, 139]]
# 2  [[501, 200, 84, 139], [504, 234, 76, 108]]
#
# 0: 352x640 1 player, 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[488, 197, 99, 133]]
#
# 0: 352x640 1 player, 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[490, 204, 94, 127]]
#
# 0: 352x640 1 player, 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 211, 92, 130]]
#
# 0: 352x640 1 player, 50.1ms
# Speed: 1.3ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 225, 95, 135]]
#
# 0: 352x640 1 player, 56.2ms
# Speed: 1.3ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[501, 232, 83, 156]]
#
# 0: 352x640 1 player, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[512, 228, 82, 171]]
#
# 0: 352x640 1 player, 53.2ms
# Speed: 1.3ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[518, 223, 81, 160]]
#
# 0: 352x640 1 player, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[522, 216, 96, 138]]
#
# 0: 352x640 1 player, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[541, 202, 103, 132]]
#
# 0: 352x640 1 player, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[543, 189, 107, 138]]
#
# 0: 352x640 1 player, 52.4ms
# Speed: 1.3ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[539, 174, 105, 152]]
#
# 0: 352x640 1 player, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[537, 160, 94, 170]]
#
# 0: 352x640 1 player, 57.1ms
# Speed: 1.4ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[528, 147, 93, 186]]
#
# 0: 352x640 1 player, 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[511, 148, 102, 194]]
#
# 0: 352x640 1 player, 54.5ms
# Speed: 1.3ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[500, 150, 102, 201]]
#
# 0: 352x640 1 player, 55.4ms
# Speed: 1.3ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[504, 152, 113, 208]]
#
# 0: 352x640 1 player, 53.5ms
# Speed: 2.7ms preprocess, 53.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[500, 153, 113, 221]]
#
# 0: 352x640 1 player, 59.0ms
# Speed: 1.8ms preprocess, 59.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[490, 163, 124, 201]]
#
# 0: 352x640 1 player, 66.3ms
# Speed: 1.4ms preprocess, 66.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[482, 173, 128, 185]]
#
# 0: 352x640 1 player, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[474, 174, 135, 209]]
#
# 0: 352x640 1 player, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[480, 175, 138, 245]]
#
# 0: 352x640 1 player, 50.2ms
# Speed: 1.2ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 177, 134, 252]]
#
# 0: 352x640 1 player, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[482, 151, 129, 256]]
#
# 0: 352x640 1 player, 56.5ms
# Speed: 1.3ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[486, 131, 143, 258]]
#
# 0: 352x640 1 player, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[498, 120, 140, 242]]
#
# 0: 352x640 1 player, 58.6ms
# Speed: 2.3ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[502, 120, 131, 189]]
#
# 0: 352x640 1 player, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[503, 118, 121, 193]]
#
# 0: 352x640 1 player, 58.4ms
# Speed: 1.3ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[496, 149, 122, 191]]
#
# 0: 352x640 1 player, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[496, 175, 109, 187]]
#
# 0: 352x640 1 player, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[490, 195, 104, 181]]
#
# 0: 352x640 1 player, 52.1ms
# Speed: 1.3ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[497, 207, 95, 191]]
#
# 0: 352x640 1 player, 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[496, 217, 93, 174]]
#
# 0: 352x640 1 player, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[499, 221, 92, 158]]
#
# 0: 352x640 1 player, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[490, 213, 101, 156]]
#
# 0: 352x640 1 player, 51.8ms
# Speed: 1.3ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[488, 214, 100, 150]]
#
# 0: 352x640 1 player, 59.7ms
# Speed: 1.5ms preprocess, 59.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[488, 219, 108, 165]]
#
# 0: 352x640 1 player, 76.6ms
# Speed: 1.4ms preprocess, 76.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 224, 104, 185]]
#
# 0: 352x640 1 player, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[481, 231, 115, 221]]
#
# 0: 352x640 1 player, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[479, 234, 122, 244]]
#
# 0: 352x640 1 player, 70.4ms
# Speed: 1.2ms preprocess, 70.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[470, 230, 146, 250]]
#
# 0: 352x640 1 player, 57.1ms
# Speed: 1.3ms preprocess, 57.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[473, 233, 152, 216]]
#
# 0: 352x640 2 players, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[493, 231, 159, 196]]
# 2  [[493, 231, 159, 196], [483, 225, 173, 329]]
#
# 0: 352x640 1 player, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[498, 222, 157, 211]]
#
# 0: 352x640 1 player, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[497, 203, 160, 241]]
#
# 0: 352x640 1 player, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[506, 201, 123, 256]]
#
# 0: 352x640 1 player, 54.7ms
# Speed: 2.1ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[489, 189, 113, 252]]
#
# 0: 352x640 1 player, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[475, 187, 122, 222]]
#
# 0: 352x640 1 player, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[472, 187, 138, 191]]
#
# 0: 352x640 1 player, 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
# 2  [[467, 186, 141, 183]]
#
# 0: 352x640 1 player, 66.4ms
# Speed: 1.3ms preprocess, 66.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 51
#      49 bound_box = (x1, y1, w, h)
#      50 tracker = OPENCV_OBJECT_TRACKERS['csrt']()
# ---> 51 trackers.add(tracker, frame, bound_box)
#      53 if boxes == ():
#      54     boxes = []
#
# KeyboardInterrupt:
