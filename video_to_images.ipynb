# %%
import cv2
import  numpy as np

# 1er partie
#the-most-intense-minecraft-pvp-battle.mp4
#minecraft-pvp-montage.mp4
#minecraft-pvp-montage-a-l-ancienne-planetpvp-2.mp4
#minecraft-pvp-montage-a-l-ancienne-planetpvp-5.mp4
#minecraft-pvp-montage-1-fr-hd.mp4

# 2eme partie
#a-minecraft-pvp-montage.mp4
#minecraft-montage-pvp-5-pas-de-skill-just-le-hack-epicube-mon-best-montage.mp4

# 3eme partie
#suis-je-toujours-le-meilleur-joueur-pvp-sur-minecraft.mp4
#minecraft-pvp-montage-a-lancienne-1.mp4
#jsuis-le-meilleur-joueur-minecraft-francais-montage-pvp-20-kohi-ctlserv.mp4

# 4eme partie
#minecraft-pvp-pot-montage.mp4
#2-dangerous-minecraft-1-16-pvp-montage.mp4
#old-clips-minecraft-pvp-montage.mp4

cap = cv2.VideoCapture('')   

img = 980
idx = 0
while True:
    frame = cap.read()[1]

    if frame is None:
        break
        
    if idx % 90 == 0:
        filename = "Desktop/images4/"+str(img)+".png"
        print(filename)
        cv2.imwrite(filename, frame)
        
        filename = "Desktop/images/"+str(img)+".png"
        cv2.imwrite(filename, frame)
        
        img += 1

    idx += 1
    cv2.imshow('Frame', frame)
    
    cv2.waitKey(30)
# Out:
# Desktop/images4/927.png
# Desktop/images4/928.png
# Desktop/images4/929.png
# Desktop/images4/930.png
# Desktop/images4/931.png
# Desktop/images4/932.png
# Desktop/images4/933.png
# Desktop/images4/934.png
# Desktop/images4/935.png
# Desktop/images4/936.png
# Desktop/images4/937.png
# Desktop/images4/938.png
# Desktop/images4/939.png
# Desktop/images4/940.png
# Desktop/images4/941.png
# Desktop/images4/942.png
# Desktop/images4/943.png
# Desktop/images4/944.png
# Desktop/images4/945.png
# Desktop/images4/946.png
# Desktop/images4/947.png
# Desktop/images4/948.png
# Desktop/images4/949.png
# Desktop/images4/950.png
# Desktop/images4/951.png
# Desktop/images4/952.png
# Desktop/images4/953.png
# Desktop/images4/954.png
# Desktop/images4/955.png
# Desktop/images4/956.png
# Desktop/images4/957.png
# Desktop/images4/958.png
# Desktop/images4/959.png
# Desktop/images4/960.png
# Desktop/images4/961.png
# Desktop/images4/962.png
# Desktop/images4/963.png
# Desktop/images4/964.png
# ...

# %%
import pyautogui
from pynput import keyboard
from PIL import Image  
import PIL

idx = 0
def on_press(key):
    if key == keyboard.Key.space:
        img = pyautogui.screenshot()
        img = img.save(str(idx)+".png")
        idx += 1
        
        
listener = keyboard.Listener(
    on_press=on_press)
listener.start()
# Out:
# This process is not trusted! Input event monitoring will not be possible until it is added to accessibility clients.
# Unhandled exception in listener callback
# Traceback (most recent call last):
#   File "/Users/maudbaconnais/anaconda3/lib/python3.11/site-packages/pynput/_util/__init__.py", line 228, in inner
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/maudbaconnais/anaconda3/lib/python3.11/site-packages/pynput/_util/darwin.py", line 265, in _handler
#     self._handle(proxy, event_type, event, refcon)
#   File "/Users/maudbaconnais/anaconda3/lib/python3.11/site-packages/pynput/keyboard/_darwin.py", line 269, in _handle
#     self.on_press(key)
#   File "/Users/maudbaconnais/anaconda3/lib/python3.11/site-packages/pynput/_util/__init__.py", line 144, in inner
#     if f(*args) is False:
#        ^^^^^^^^
#   File "/var/folders/7d/2x5g6ykn5wx82f55l_ndk3980000gn/T/ipykernel_30021/731295042.py", line 10, in on_press
# ...

# %%
#!pip install pyautogui
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
#3 : 720-534
#2 : 533-415
#1 : 478-0
